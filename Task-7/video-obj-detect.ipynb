# %% [markdown]
# ### Craeted By:Mrinal Bhan

# %% [markdown]
# ### Tasks
#
# **Experiment Number -01:** Write a program to implement real-time object detection in a video stream.
# Hint: Detect and draw bounding boxes around objects in a live video feed using pre-trained object
# detection models like YOLO, Faster R-CNN, or SSD.

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  

results = model('banana.mp4', save=True)  # predict on an video
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Example:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/3859) /mnt/e/acad/Semester_5/computer-vision/lab/Lab-7/banana.mp4: 384x640 3 persons, 2 bananas, 113.8ms
# video 1/1 (2/3859) /mnt/e/acad/Semester_5/computer-vision/lab/Lab-7/banana.mp4: 384x640 5 persons, 2 bananas, 6.0ms
# video 1/1 (3/3859) /mnt/e/acad/Semester_5/computer-vision/lab/Lab-7/banana.mp4: 384x640 1 person, 1 banana, 6.3ms
# ...
